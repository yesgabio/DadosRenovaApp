# %%
from lxml.html import fromstring
import requests
import pandas as pd
from IPython.display import Markdown


#LISTA DE CIDADES, NUMERO IDENTIFICADOR E URL DE ACESSO.
url = 'https://resultados.tre-rs.jus.br/eleicoes/2014/1turno/'
req = requests.get(url)
root = fromstring(req.text)
ul = root.xpath('.//ul[@id="main_ul"]')[0]
cities = []
for li in ul.xpath('.//li')[0:]:
    cities.append({
        'name': li.xpath('.//a')[0].text_content(),
        'href': li.xpath('.//a')[0].attrib['href'],
        'url': url + li.xpath('.//a')[0].attrib['href']
    })
#display(pd.DataFrame(cities)) #IMPRIMIR EM FORMATO DE TABELA AS INFORMAÇÕES DAS CIDADES

#LISTA DE ELEITOS DO ACESSO AO RS (pois 2018 foram eleições gerais)
url = cities[0]["url"]
req = requests.get(url)
root = fromstring(req.text)
tables = root.xpath('.//table[@summary="Votação dos candidatos na UF"]')
h2_s = root.xpath('.//h2')
data = []
eleitos_class = ["lr_even eleito ", "eleito "]
for index,table in enumerate(tables):
    data.append({
        'title': h2_s[index].text_content(),
        'values': []
    })
    for classe in eleitos_class:
        for tr in table.xpath(f'.//tr[@class="{classe}"]'):
            data[-1]['values'].append({ 
            'name': tr.xpath('.//a')[0].text_content(),
            'partido': tr.xpath('.//td')[3].text_content(),
            'votação': tr.xpath('.//td')[4].text_content()
        })

#ELEITOS SEGUNDO TURNO
url2 = 'https://resultados.tre-rs.jus.br/eleicoes/2014/2turno/RS.html'
req = requests.get(url2)
root = fromstring(req.text)
tables = root.xpath('.//table[@summary="Votação dos candidatos na UF"]')
h2_s = root.xpath('.//h2')
data2 = []
eleitos_class = ["lr_even eleito ", "eleito "]
for index,table in enumerate(tables):
    data2.append({
        'title': h2_s[index].text_content(),
        'values': []
    })
    for classe in eleitos_class:
        for tr in table.xpath(f'.//tr[@class="{classe}"]'):
            data2[-1]['values'].append({ 
            'name': tr.xpath('.//a')[0].text_content(),
            'partido': tr.xpath('.//td')[3].text_content(),
            'votação': tr.xpath('.//td')[4].text_content()
        })


# IMPRIMIR AS INFORMAÇÕES EM FORMATO DE TABELA
for d in data:
    display(Markdown(f"# PRIMEIRO TURNO"))
    display(Markdown(f"## {d['title']}"))
    display(pd.DataFrame(d['values']))
for d in data2:
    display(Markdown(f"# SEGUNDO TURNO"))
    display(Markdown(f"## {d['title']}"))
    display(pd.DataFrame(d['values']))
# Out:
# # PRIMEIRO TURNO
# ## Presidente
# Empty DataFrame
# Columns: []
# Index: []
# # PRIMEIRO TURNO
# ## Governador
#                         name partido  votação
# 0  TARSO FERNANDO HERZ GENRO      PT  2005743
# 1           JOS� IVO SARTORI    PMDB  2487889
# # PRIMEIRO TURNO
# ## Senador
#                    name partido  votação
# 12  ANTONIO VALDECI OLIVEIRA DE OLIVEIRA       PT   44501
# 13                     ADOLFO JOS� BRITO       PP   44224
# 14                  NELSON LUIZ DA SILVA       PT   42102
# 15          JOS� SIDNEY NUNES DE ALMEIDA       PT   41609
# 16          MARIO JARDEL ALMEIDA RIBEIRO      PSD   41227
# 17               GABRIEL VIEIRA DE SOUZA     PMDB   39998
# 18                   ALVARO DAVI BOESSIO     PMDB   37933
# 19              ENIO EGON BERGMANN BACCI      PDT   37148
# 20                 SERGIO BERGONSI TURRA       PP   36518
# 21                   JO�O ERVINO FISCHER       PP   35696
# 22              ALTEMIR ANTONIO TORTELLI       PT   33879
# 23                 VOLNEI DA SILVA ALVES       PR   33255
# 24                         ADILSON TROCA     PSDB   32579
# 25                LIZIANE BAYER DA COSTA      PSB   29121
# 26                          JULIANO ROSO  PC do B   17092
# 27          MANUELA PINTO VIEIRA D AVILA  PC do B  222436
# 28          MARLON ARATOR SANTOS DA ROSA      PDT   91100
# 29                    JOAO EDEGAR PRETTO       PT   73122
# 30             PEDRO BANDARRA WESTPHALEN       PP   65134
# 31                       GILMAR SOSSELLA      PDT   57490
# 32              F�BIO DE OLIVEIRA BRANCO     PMDB   57135
# 33                     EDSON MEURER BRUM     PMDB   55887
# 34               ALOISIO TALSO CLASSMANN      PTB   52771
# 35           JEFERSON OLIVEIRA FERNANDES       PT   50437
# 36             JORGE CLADISTONE POZZOBOM     PSDB   48244
# 37           LU�S AUGUSTO BARCELLOS LARA      PTB   47738
# 38                   REGINA MARIA BECKER      PDT   46788
# 39                      ALEXANDRE POSTAL     PMDB   44856
# 40                   ELTON ROBERTO WEBER      PSB   44444
# 41                  PEDRO OZORIO PEREIRA     PSDB   43535
# 42            STELA BEATRIZ FARIAS LOPES       PT   41719
# 43                  VILMAR PERIN ZANCHIN     PMDB   41488
# 44         MAURICIO ALEXANDRE DZIEDRICKI      PTB   40009
# 45             MIRIAM PAZ GARCEZ MARRONI       PT   39409
# 46                      GILBERTO CAPOANI     PMDB   36535
# 47              PEDRO LUIZ FAGUNDES RUAS     PSOL   36230
# 48                 DIOGENES LUIS BASEGIO      PDT   33829
# 49                    TIAGO CHANAN SIMON     PMDB   32717
# 50     AD�O ROBERTO RODRIGUES VILLAVERDE       PT   31927
# 51               VOLMIR JOSE MIKI BREIER      PSB   28855
# 52                     ANY MACHADO ORTIZ      PPS   22553
# 53    MIGUEL CONSTANTINO ROSSO BIANCHINI      PPL   13515
# 54                  JO�O OT�VIO REINELLI       PV    9098
# # SEGUNDO TURNO
# ## Presidente
# Empty DataFrame
# Columns: []
# Index: []
# # SEGUNDO TURNO
# ## Governador
#                name partido  votação
# 0  JOS� IVO SARTORI    PMDB  3859611
